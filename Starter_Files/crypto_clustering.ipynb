# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
#import hvplot.pandas
#import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame

# %%
# Alternatively, use the provided csv file:
from pathlib import Path
file_path = Path("Resources/crypto_data.csv")

# Create a DataFrame
cryptocurr_df = pd.read_csv(file_path, index_col=0)
cryptocurr_df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
cryptocurr_df2=cryptocurr_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']]
cryptocurr_df2.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Keep only cryptocurrencies that are trading
cryptocurr_df_trading = cryptocurr_df2[cryptocurr_df2["IsTrading"] == True]
cryptocurr_df_trading.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Keep only cryptocurrencies with a working algorithm
cryptocurr_df_working = cryptocurr_df_trading[cryptocurr_df_trading["Algorithm"] != "N/A"]
cryptocurr_df_working.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Remove the "IsTrading" column
cryptocurr_df_working2 = cryptocurr_df_working.drop("IsTrading", axis=1)
cryptocurr_df_working2.head()
# Out:
#       CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       PoW              NaN          611000
# 808        808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
# Remove rows with at least 1 null value
cryptocurr_df_working3 = cryptocurr_df_working2.dropna(axis=0, how="any")
cryptocurr_df_working3.head()
# Out:
#        CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 808         808   SHA-256   PoW/PoS     0.000000e+00               0
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07        21000000

# %%
# Remove rows with cryptocurrencies having no coins mined
cryptocurr_df_working4 = cryptocurr_df_working3[cryptocurr_df_working3["TotalCoinsMined"] > 0]
cryptocurr_df_working4.head(10)
# Out:
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
# ZEC              ZCash        Equihash       PoW     7.383056e+06
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000
# ...

# %%
# Drop rows where there are 'N/A' text values
cryptocurr_df_working5 = cryptocurr_df_working4[cryptocurr_df_working4.iloc[:] != 'N/A'].dropna()
cryptocurr_df_working5.head(10)
# Out:
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
# ZEC              ZCash        Equihash       PoW     7.383056e+06
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000
# ...

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coins_name = pd.DataFrame(cryptocurr_df_working5["CoinName"], index=cryptocurr_df_working5.index)
coins_name.head()
# Out:
#        CoinName
# 42      42 Coin
# 404     404Coin
# 1337  EliteCoin
# BTC     Bitcoin
# ETH    Ethereum

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
cryptocurr_df_working6 = cryptocurr_df_working5.drop("CoinName", axis=1)
cryptocurr_df_working6.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      Scrypt   PoW/PoS     4.199995e+01              42
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337       X13   PoW/PoS     2.927942e+10    314159265359
# BTC    SHA-256       PoW     1.792718e+07        21000000
# ETH     Ethash       PoW     1.076842e+08               0

# %%
# Create dummy variables for text features
X = pd.get_dummies(data=cryptocurr_df_working6, columns=["Algorithm", "ProofType"])
print(X.shape)
X.head(10)
# Out:
# (532, 98)
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# LTC      6.303924e+07        84000000                                 0
# DASH     9.031294e+06        22000000                                 0
# XMR      1.720114e+07               0                                 0
# ETC      1.133597e+08       210000000                                 0
# ZEC      7.383056e+06        21000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                0                  0                   0                0
# ...

# %%
# Standardize data
X = StandardScaler().fit_transform(X)
X[:1]
# Out:
# array([[-0.11710817, -0.1528703 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.07530656, -0.0433963 , -0.06142951, -0.06142951,
#         -0.0433963 , -0.0433963 , -0.19245009, -0.06142951, -0.09740465,
#         -0.0433963 , -0.11547005, -0.07530656, -0.0433963 , -0.0433963 ,
#         -0.15191091, -0.0433963 , -0.13118084, -0.0433963 , -0.0433963 ,
#         -0.08703883, -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.08703883, -0.08703883, -0.08703883,
#         -0.0433963 , -0.13118084, -0.13840913, -0.13840913, -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.07530656, -0.18168574, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.07530656, -0.15826614, -0.31491833,
#         -0.0433963 , -0.08703883, -0.07530656, -0.06142951,  1.38675049,
#         -0.0433963 , -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
# ...

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
n_comp = 3
pca = PCA(n_components=n_comp)
principal_components = pca.fit_transform(X)
principal_components
# Out:
# array([[-0.33818425,  1.07044039, -0.61416556],
#        [-0.32153467,  1.07081434, -0.6145005 ],
#        [ 2.31018062,  1.63351349, -0.62778065],
#        ...,
#        [ 0.32663143, -2.31966824,  0.43011938],
#        [-0.14565822, -2.10840914,  0.58800915],
#        [-0.30053632,  0.88467298, -0.36210691]])

# %%
# Create a DataFrame with the principal components data
col_names = [f"PC {i}" for i in range(1, n_comp + 1)]
pcs_df = pd.DataFrame(principal_components, columns=col_names, index=cryptocurr_df_working6.index)
print(pcs_df.shape)
pcs_df.head()
# Out:
# (532, 3)
#           PC 1      PC 2      PC 3
# 42   -0.338184  1.070440 -0.614166
# 404  -0.321535  1.070814 -0.614500
# 1337  2.310181  1.633513 -0.627781
# BTC  -0.140374 -1.391756  0.226887
# ETH  -0.153501 -2.069499  0.366687

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
#please note HVPLOT not working
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-c740a3287217> in <module>
#      11 elbow_data = {"k": k, "inertia": inertia}
#      12 df_elbow = pd.DataFrame(elbow_data)
# ---> 13 df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
#      14
#
# ~\anaconda3\envs\nlpenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'hvplot'

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = pd.concat([cryptocurr_df_working6, pcs_df], axis=1, sort=False)
clustered_df["CoinName"] = coins_name["CoinName"]
clustered_df["Class"] = model.labels_
print(clustered_df.shape)
clustered_df.head(10)
# Out:
# (532, 9)
#            Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1  \
# 42            Scrypt   PoW/PoS     4.199995e+01              42 -0.338184
# 404           Scrypt   PoW/PoS     1.055185e+09       532000000 -0.321535
# 1337             X13   PoW/PoS     2.927942e+10    314159265359  2.310181
# BTC          SHA-256       PoW     1.792718e+07        21000000 -0.140374
# ETH           Ethash       PoW     1.076842e+08               0 -0.153501
# LTC           Scrypt       PoW     6.303924e+07        84000000 -0.171141
# DASH             X11   PoW/PoS     9.031294e+06        22000000 -0.390844
# XMR   CryptoNight-V7       PoW     1.720114e+07               0 -0.146991
# ETC           Ethash       PoW     1.133597e+08       210000000 -0.151944
# ZEC         Equihash       PoW     7.383056e+06        21000000 -0.145657
#
#           PC 2      PC 3          CoinName  Class
# 42    1.070440 -0.614166           42 Coin      0
# ...

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 3D-Scatter with the PCA data and the clusters
#please note HVPLOT not working
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-212d0664b4d0> in <module>
#       1 # Create a 3D-Scatter with the PCA data and the clusters
#       2 #please note HVPLOT not working
# ----> 3 fig = px.scatter_3d(
#       4     clustered_df,
#       5     x="PC 1",
#
# NameError: name 'px' is not defined

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
clustered_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1  \
# 42         Scrypt   PoW/PoS     4.199995e+01              42 -0.338184
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000 -0.321535
# 1337          X13   PoW/PoS     2.927942e+10    314159265359  2.310181
# BTC       SHA-256       PoW     1.792718e+07        21000000 -0.140374
# ETH        Ethash       PoW     1.076842e+08               0 -0.153501
# ...           ...       ...              ...             ...       ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000  2.487692
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000 -0.336231
# BDX   CryptoNight       PoW     9.802226e+08      1400222610  0.326631
# ZEN      Equihash       PoW     7.296538e+06        21000000 -0.145658
# XBC        Scrypt       PoS     1.283270e+05         1000000 -0.300536
#
#           PC 2      PC 3     CoinName  Class
# 42    1.070440 -0.614166      42 Coin      0
# ...

# %%
# Print the total number of tradable cryptocurrencies
print(f"There are {clustered_df.shape[0]} tradable cryptocurrencies.")
# Out:
# There are 532 tradable cryptocurrencies.

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
mm_scaler = MinMaxScaler()
plot_data = mm_scaler.fit_transform(
    clustered_df[["TotalCoinSupply", "TotalCoinsMined"]]
)
plot_df = pd.DataFrame(
    plot_data, columns=["TotalCoinSupply", "TotalCoinsMined"], index=clustered_df.index
)
plot_df["CoinName"] = clustered_df["CoinName"]
plot_df["Class"] = clustered_df["Class"]
plot_df.head()
# Out:
#       TotalCoinSupply  TotalCoinsMined   CoinName  Class
# 42       4.200000e-11         0.000000    42 Coin      0
# 404      5.320000e-04         0.001066    404Coin      0
# 1337     3.141593e-01         0.029576  EliteCoin      0
# BTC      2.100000e-05         0.000018    Bitcoin      2
# ETH      0.000000e+00         0.000109   Ethereum      2

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
#please note HVPLOT not working
